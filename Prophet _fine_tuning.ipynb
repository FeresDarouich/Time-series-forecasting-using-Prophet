# %% [markdown]
# Importations

# %%
import pandas as pd
import numpy as np

# %%
# !pip install prophet
# Out:
# Requirement already satisfied: prophet in /usr/local/lib/python3.10/dist-packages (1.1.5)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.2.0)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.23.5)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from prophet) (3.7.1)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.5.3)
# Requirement already satisfied: holidays>=0.25 in /usr/local/lib/python3.10/dist-packages (from prophet) (0.41)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.10/dist-packages (from prophet) (4.66.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from prophet) (6.1.1)
# Requirement already satisfied: stanio~=0.3.0 in /usr/local/lib/python3.10/dist-packages (from cmdstanpy>=1.0.4->prophet) (0.3.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from holidays>=0.25->prophet) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (3.1.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.4->prophet) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->holidays>=0.25->prophet) (1.16.0)

# %%
holidays = pd.read_csv("holidays.csv")

# %%
df = pd.read_excel('/content/TPS IN.xlsx')
df = df.iloc[104:]
voix = df[['DATES','TPS_VOIX']]
voix.dropna(inplace= True)
# Out:
# <ipython-input-11-a94c752dc3eb>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   voix.dropna(inplace= True)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  xs = series['DATES']
  ys = series['TPS_VOIX']

  plt.plot(xs, ys, label=series_name)

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = voix.sort_values('DATES', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('DATES')
plt.ylabel('TPS_VOIX')
# Out:
# Text(0, 0.5, 'TPS_VOIX')

# %%
train_percentage = 0.8
voix.columns=['ds', 'y']
train_size = int(len(voix) * train_percentage)
train_voix = voix.iloc[:train_size]
test_voix = voix.iloc[train_size:]

# %%
from prophet import Prophet
holidays = pd.read_csv("holidays.csv")
model = Prophet(
                      growth='linear',

                     changepoint_range=0.7,
                     holidays=holidays,
                     seasonality_mode='additive',
                     seasonality_prior_scale=0.6,
                     holidays_prior_scale=1.0,
                     changepoint_prior_scale=0.3,
)
model.fit(train_voix)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp2dotpqav/4l0sdtwv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp2dotpqav/byf41opd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62989', 'data', 'file=/tmp/tmp2dotpqav/4l0sdtwv.json', 'init=/tmp/tmp2dotpqav/byf41opd.json', 'output', 'file=/tmp/tmp2dotpqav/prophet_modelkfof5xdu/prophet_model-20240201202519.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:25:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:25:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
start_date = '2023-09-01'
end_date = pd.to_datetime(start_date) + pd.DateOffset(months=3) - pd.DateOffset(days=1)
date_range = pd.date_range(start=start_date, end=end_date, freq='D')
future = pd.DataFrame({'ds': date_range})
print(future)
# Out:
#            ds
# 0  2023-09-01
# 1  2023-09-02
# 2  2023-09-03
# 3  2023-09-04
# 4  2023-09-05
# ..        ...
# 86 2023-11-26
# 87 2023-11-27
# 88 2023-11-28
# 89 2023-11-29
# 90 2023-11-30
#
# [91 rows x 1 columns]

# %%
test_forecast = model.predict(test_voix[['ds']])
test_predictions = test_forecast[['yhat']]
actual_values = test_voix['y'].values

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
mae = mean_absolute_error(actual_values, test_predictions)
mse = mean_squared_error(actual_values, test_predictions)
rmse = np.sqrt(mse)

print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Absolute Error (MAE): 24.84964379612685
# Mean Squared Error (MSE): 815.7795724303812
# Root Mean Squared Error (RMSE): 28.561855199380542

# %%
forecast = model.predict(future)
date_range = forecast['ds']
forecasted_values = forecast['yhat']
lower_bound = forecast['yhat_lower']
upper_bound = forecast['yhat_upper']
plt.figure(figsize=(20, 6))
plt.plot(date_range, forecasted_values, label='Forecast', color='blue')
plt.fill_between(date_range, lower_bound, upper_bound, color='skyblue', alpha=0.3, label='Confidence Interval')
plt.plot(voix['ds'],voix['y'])
plt.xlabel('Date')
plt.ylabel('TPS_VOIX')
plt.title('Forecast')
plt.legend()
plt.grid(True)
plt.show()

# %%
import itertools
from tqdm import tqdm
from prophet import Prophet
from prophet.diagnostics import cross_validation, performance_metrics
import pandas as pd

param_grid = {
    'growth': ['linear'],
    'n_changepoints': [0,2,4,6,10],
    'changepoint_range': [0.8, 0.9],
    'seasonality_mode': ['additive', 'multiplicative'],
    'seasonality_prior_scale': [0.5, 0.8, 1.0],
    'holidays_prior_scale': [0.8, 1.0, 1.2],
    'changepoint_prior_scale': [0.05, 0.1, 0.2],
}

# Generate all combinations of parameters
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())] # 540
rmses = []  # Store the RMSEs for each params here

# Use cross-validation to evaluate all parameters
tuning_results = pd.DataFrame(all_params)
tuning_results['rmse'] = 0.0

with tqdm(total=len(all_params), desc="Tuning progress") as pbar:
    for i, params in enumerate(all_params):
        m = Prophet(**params).fit(voix)  # Fit model with given params
        df_cv = cross_validation(m, horizon='45 days', parallel="processes")
        df_p = performance_metrics(df_cv, rolling_window=1)
        rmses.append(df_p['rmse'].values[0])
        tuning_results.at[i, 'rmse'] = df_p['rmse'].values[0]
        pbar.update(1)

# Find the best parameters
best_params_index = tuning_results['rmse'].idxmin()
best_params = tuning_results.iloc[best_params_index]
print("Best Parameters:")
print(best_params)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Tuning progress:  81%|████████  | 438/540 [14:58<03:11,  1.88s/it]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp2dotpqav/mmvp_53j.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp2dotpqav/yz4j18vk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51825', 'data', 'file=/tmp/tmp2dotpqav/mmvp_53j.json', 'init=/tmp/tmp2dotpqav/yz4j18vk.json', 'output', 'file=/tmp/tmp2dotpqav/prophet_modellr6xvx02/prophet_model-20240201190422.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:04:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:04:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 4 forecasts with cutoffs between 2023-05-10 12:00:00 and 2023-07-17 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f4c7a26dab0>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp2dotpqav/toxmjb1n.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp2dotpqav/jh5hurkg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp2dotpqav/icwb1mj6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp2dotpqav/dyqw8g6t.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=57138', 'data', 'file=/tmp/tmp2dotpqav/jh5hurkg.json', 'init=/tmp/tmp2dotpqav/icwb1mj6.json', 'output', 'file=/tmp/tmp2dotpqav/prophet_model9cdxlkvx/prophet_model-20240201190422.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:04:22 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72682', 'data', 'file=/tmp/tmp2dotpqav/toxmjb1n.json', 'init=/tmp/tmp2dotpqav/dyqw8g6t.json', 'output', 'file=/tmp/tmp2dotpqav/prophet_modelneolzq9_/prophet_model-20240201190422.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:04:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:04:22 - cmdstanpy - INFO - Chain [1] done processing
# 19:04:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp2dotpqav/mes1_qu6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp2dotpqav/hpamu0vq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp2dotpqav/iawx9emz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp2dotpqav/bv7d94l3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77248', 'data', 'file=/tmp/tmp2dotpqav/mes1_qu6.json', 'init=/tmp/tmp2dotpqav/bv7d94l3.json', 'output', 'file=/tmp/tmp2dotpqav/prophet_modelo7mu83tm/prophet_model-20240201190423.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:04:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27588', 'data', 'file=/tmp/tmp2dotpqav/hpamu0vq.json', 'init=/tmp/tmp2dotpqav/iawx9emz.json', 'output', 'file=/tmp/tmp2dotpqav/prophet_model40ryed3e/prophet_model-20240201190423.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:04:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:04:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 19:04:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Tuning progress:  81%|████████▏ | 439/540 [15:00<03:03,  1.82s/it]INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp2dotpqav/mpwp6b0k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp2dotpqav/m38baar6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=82991', 'data', 'file=/tmp/tmp2dotpqav/mpwp6b0k.json', 'init=/tmp/tmp2dotpqav/m38baar6.json', 'output', 'file=/tmp/tmp2dotpqav/prophet_modelgyoiwjap/prophet_model-20240201190423.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:04:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:04:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 4 forecasts with cutoffs between 2023-05-10 12:00:00 and 2023-07-17 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f4c7a266f80>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp2dotpqav/gtb3la6_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp2dotpqav/m2hc1h3f.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=16919', 'data', 'file=/tmp/tmp2dotpqav/gtb3la6_.json', 'init=/tmp/tmp2dotpqav/m2hc1h3f.json', 'output', 'file=/tmp/tmp2dotpqav/prophet_model9k61ndar/prophet_model-20240201190424.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp2dotpqav/3xeg96lp.json
# 19:04:24 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp2dotpqav/zn2cahe8.json
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42770', 'data', 'file=/tmp/tmp2dotpqav/3xeg96lp.json', 'init=/tmp/tmp2dotpqav/zn2cahe8.json', 'output', 'file=/tmp/tmp2dotpqav/prophet_modelvp30p0xj/prophet_model-20240201190424.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:04:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:04:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 19:04:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp2dotpqav/g9g73co0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp2dotpqav/849eafuz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=48212', 'data', 'file=/tmp/tmp2dotpqav/g9g73co0.json', 'init=/tmp/tmp2dotpqav/849eafuz.json', 'output', 'file=/tmp/tmp2dotpqav/prophet_
csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:07:14 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99956', 'data', 'file=/tmp/tmp2dotpqav/36n6ed25.json', 'init=/tmp/tmp2dotpqav/fnz46vbi.json', 'output', 'file=/tmp/tmp2dotpqav/prophet_modelmxa6o2kw/prophet_model-20240201190714.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# INFO:cmdstanpy:Chain [1] start processing
# 19:07:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:07:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 19:07:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp2dotpqav/7j79b3km.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp2dotpqav/ntpbcb22.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=73150', 'data', 'file=/tmp/tmp2dotpqav/7j79b3km.json', 'init=/tmp/tmp2dotpqav/ntpbcb22.json', 'output', 'file=/tmp/tmp2dotpqav/prophet_model880m3rdy/prophet_model-20240201190715.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp2dotpqav/cgvp0ct9.json
# 19:07:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp2dotpqav/qarjrauk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29840', 'data', 'file=/tmp/tmp2dotpqav/cgvp0ct9.json', 'init=/tmp/tmp2dotpqav/qarjrauk.json', 'output', 'file=/tmp/tmp2dotpqav/prophet_modeluasnwc9m/prophet_model-20240201190715.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:07:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:07:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 19:07:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Tuning progress: 100%|██████████| 540/540 [17:52<00:00,  1.99s/it]
# Best Parameters:
# growth                             linear
# n_changepoints                          4
# changepoint_range                     0.9
# seasonality_mode           multiplicative
# seasonality_prior_scale               0.5
# holidays_prior_scale                  0.8
# changepoint_prior_scale              0.05
# rmse                            78.692303
# Name: 297, dtype: object

# %%
best_params = all_params[np.argmin(rmses)]
print(best_params)
# Out:
# {'growth': 'linear', 'n_changepoints': 4, 'changepoint_range': 0.9, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.5, 'holidays_prior_scale': 0.8, 'changepoint_prior_scale': 0.05}

# %%
holidays = pd.read_csv("holidays.csv")
vmodel = Prophet(
                      growth='linear',

                      n_changepoints=4,
                     changepoint_range=0.9,
                     holidays=holidays,
                     seasonality_mode='multiplicative',
                     seasonality_prior_scale=0.5,
                     holidays_prior_scale=0.8,
                     changepoint_prior_scale=0.05,
)
vmodel.fit(train_voix)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp2dotpqav/vxo4bmh3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp2dotpqav/l2ml2pop.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59556', 'data', 'file=/tmp/tmp2dotpqav/vxo4bmh3.json', 'init=/tmp/tmp2dotpqav/l2ml2pop.json', 'output', 'file=/tmp/tmp2dotpqav/prophet_modelsgir3egk/prophet_model-20240201202128.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:21:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:21:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
test_forecast = vmodel.predict(test_voix[['ds']])
test_predictions = test_forecast[['yhat']]
actual_values = test_voix['y'].values

# %%
mae = mean_absolute_error(actual_values, test_predictions)
mse = mean_squared_error(actual_values, test_predictions)
rmse = np.sqrt(mse)

print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Absolute Error (MAE): 18.74661132557972
# Mean Squared Error (MSE): 686.584855940678
# Root Mean Squared Error (RMSE): 26.202764280523496

# %%
forecast = vmodel.predict(future)
print(forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())
# Out:
#            ds        yhat  yhat_lower  yhat_upper
# 86 2023-11-26  485.887144  395.867472  586.981310
# 87 2023-11-27  618.629338  535.458907  706.863368
# 88 2023-11-28  586.891690  501.469302  678.960445
# 89 2023-11-29  607.742289  518.409397  690.970438
# 90 2023-11-30  602.902765  514.967002  691.009320

# %%
date_range = forecast['ds']
forecasted_values = forecast['yhat']
lower_bound = forecast['yhat_lower']
upper_bound = forecast['yhat_upper']
plt.figure(figsize=(20, 6))
plt.plot(date_range, forecasted_values, label='Forecast', color='blue')
plt.fill_between(date_range, lower_bound, upper_bound, color='skyblue', alpha=0.3, label='Confidence Interval')
plt.plot(voix['ds'],voix['y'])
plt.xlabel('Date')
plt.ylabel('TPS_VOIX')
plt.title('Forecast')
plt.legend()
plt.grid(True)
plt.show()
